# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
sns.set_context('talk')
sns.set_theme(style="whitegrid")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
armedforces_tot = pd.read_csv('/content/drive/MyDrive/dataset/armedforce.csv')

# %%
g20 = ['United States', 'Russian Federation', 'China', 'India', 'European Union', 'Brazil',
       'Argentina','Australia','Canada','France','Germany','Indonesia','Italy','Japan',
       'South Korea','Mexico','Saudi Arabia','South Africa','Turkey','United Kingdom','Austria','Belgium','Bulgaria','Croatia','Cyprus',
       'Czech Republic','Denmark','Estonia','Finland','Greece','Hungary','Ireland','Latvia','Lithuania','Luxembourg','Malta','Netherlands',
       'Poland','Portugal','Romania','Slovenia','Spain','Sweden']

# %%
armedforces_tot[armedforces_tot['Country Name'].str.contains('Korea')]
# Out:
#                   Country Name Country Code                 Indicator Name  \
# 124                Korea, Rep.          KOR  Armed forces personnel, total
# 191  Korea, Dem. People’s Rep.          PRK  Armed forces personnel, total
#
#      Indicator Code  1960  1961  1962  1963  1964  1965  ...       2011  \
# 124  MS.MIL.TOTL.P1   NaN   NaN   NaN   NaN   NaN   NaN  ...   659500.0
# 191  MS.MIL.TOTL.P1   NaN   NaN   NaN   NaN   NaN   NaN  ...  1379000.0
#
#           2012       2013       2014       2015       2016       2017  2018  \
# 124   659500.0   659500.0   632500.0   634500.0   634000.0   634000.0   NaN
# 191  1379000.0  1379000.0  1379000.0  1379000.0  1469000.0  1469000.0   NaN
#
#      2019  Unnamed: 64
# 124   NaN          NaN
# 191   NaN          NaN
#
# [2 rows x 65 columns]

# %%
armedforces_tot["Country Name"].replace({"Korea, Rep.": "South Korea"},inplace=True)

# %%
af_g20 = armedforces_tot[armedforces_tot['Country Name'].isin(g20)]
af_g20 = af_g20.T.reset_index()
af_g20.columns = af_g20.iloc[0]
af_g20 = af_g20.drop([0,1,2,3]).reset_index()
af_g20 = af_g20.drop('index', axis=1)
af_g20 = af_g20.rename(columns = {'Country Name': 'Years'})
af_g20 = af_g20[af_g20['Years'] != 'Unnamed: 64']
af_g20['Years'] = af_g20['Years'].astype(int)
af_g20 = af_g20[af_g20['Years'] > 1990]
af_g20.China = af_g20.China.astype(float)
af_g20.India = af_g20.India.astype(float)
af_g20.Brazil = af_g20.Brazil.astype(float)
af_g20.Argentina = af_g20.Argentina.astype(float)
af_g20.Australia = af_g20.Australia.astype(float)
af_g20.Canada = af_g20.Canada.astype(float)
af_g20.France = af_g20.France.astype(float)
af_g20.Germany = af_g20.Germany.astype(float)
af_g20.Indonesia = af_g20.Indonesia.astype(float)
af_g20.Italy = af_g20.Italy.astype(float)
af_g20.Japan = af_g20.Japan.astype(float)
af_g20.Mexico = af_g20.Mexico.astype(float)
af_g20.Austria = af_g20.Austria.astype(float)
af_g20.Turkey = af_g20.Turkey.astype(float)
af_g20.Belgium = af_g20.Belgium.astype(float)
af_g20.Bulgaria = af_g20.Bulgaria.astype(float)
af_g20.Croatia = af_g20.Croatia.astype(float)
af_g20.Cyprus = af_g20.Cyprus.astype(float)
af_g20.Denmark = af_g20.Denmark.astype(float)
af_g20.Estonia = af_g20.Estonia.astype(float)
af_g20.Finland = af_g20.Finland.astype(float)
af_g20.Hungary = af_g20.Hungary.astype(float)
af_g20.Ireland = af_g20.Ireland.astype(float)
af_g20.Latvia = af_g20.Latvia.astype(float)
af_g20.Lithuania = af_g20.Lithuania.astype(float)
af_g20.Luxembourg = af_g20.Luxembourg.astype(float)
af_g20.Malta = af_g20.Malta.astype(float)
af_g20.Netherlands = af_g20.Netherlands.astype(float)
af_g20.Poland = af_g20.Poland.astype(float)
af_g20.Portugal = af_g20.Portugal.astype(float)
af_g20.Romania = af_g20.Romania.astype(float)
af_g20.Slovenia = af_g20.Slovenia.astype(float)
af_g20.Spain = af_g20.Spain.astype(float)
af_g20.Sweden = af_g20.Sweden.astype(float)
af_g20.Greece = af_g20.Greece.astype(float)
af_g20['United States'] = af_g20['United States'].astype(float)
af_g20['Russian Federation'] = af_g20['Russian Federation'].astype(float)
af_g20['European Union'] = af_g20['European Union'].astype(float)
af_g20['South Korea'] = af_g20['South Korea'].astype(float)
af_g20['Saudi Arabia'] = af_g20['Saudi Arabia'].astype(float)
af_g20['South Africa'] = af_g20['South Africa'].astype(float)
af_g20['United Kingdom'] = af_g20['United Kingdom'].astype(float)
af_g20['Czech Republic'] = af_g20['Czech Republic'].astype(float)

# %%
milexp_gdp = pd.read_csv('/content/drive/MyDrive/dataset/mill expenditure.csv')

# %%
milexp_gdp["Country Name"].replace({"Korea, Rep.": "South Korea"},inplace=True)

# %%
milexp_g20 = milexp_gdp[milexp_gdp['Country Name'].isin(g20)]
milexp_g20 = milexp_g20.T.reset_index()
milexp_g20.columns = milexp_g20.iloc[0]
milexp_g20 = milexp_g20.drop([0,1,2,3]).reset_index()
milexp_g20 = milexp_g20.drop('index', axis=1)
milexp_g20 = milexp_g20.rename(columns = {'Country Name': 'Years'})
milexp_g20 = milexp_g20[milexp_g20['Years'] != 'Unnamed: 64']
milexp_g20['Years'] = milexp_g20['Years'].astype(int)
milexp_g20 = milexp_g20[milexp_g20['Years'] > 1990]
milexp_g20.China = milexp_g20.China.astype(float)
milexp_g20.India = milexp_g20.India.astype(float)
milexp_g20.Brazil = milexp_g20.Brazil.astype(float)
milexp_g20.Argentina = milexp_g20.Argentina.astype(float)
milexp_g20.Australia = milexp_g20.Australia.astype(float)
milexp_g20.Canada = milexp_g20.Canada.astype(float)
milexp_g20.France = milexp_g20.France.astype(float)
milexp_g20.Germany = milexp_g20.Germany.astype(float)
milexp_g20.Indonesia = milexp_g20.Indonesia.astype(float)
milexp_g20.Italy = milexp_g20.Italy.astype(float)
milexp_g20.Japan = milexp_g20.Japan.astype(float)
milexp_g20.Mexico = milexp_g20.Mexico.astype(float)
milexp_g20.Austria = milexp_g20.Austria.astype(float)
milexp_g20.Turkey = milexp_g20.Turkey.astype(float)
milexp_g20.Belgium = milexp_g20.Belgium.astype(float)
milexp_g20.Bulgaria = milexp_g20.Bulgaria.astype(float)
milexp_g20.Croatia = milexp_g20.Croatia.astype(float)
milexp_g20.Cyprus = milexp_g20.Cyprus.astype(float)
milexp_g20.Denmark = milexp_g20.Denmark.astype(float)
milexp_g20.Estonia = milexp_g20.Estonia.astype(float)
milexp_g20.Finland = milexp_g20.Finland.astype(float)
milexp_g20.Hungary = milexp_g20.Hungary.astype(float)
milexp_g20.Ireland = milexp_g20.Ireland.astype(float)
milexp_g20.Latvia = milexp_g20.Latvia.astype(float)
milexp_g20.Lithuania = milexp_g20.Lithuania.astype(float)
milexp_g20.Luxembourg = milexp_g20.Luxembourg.astype(float)
milexp_g20.Malta = milexp_g20.Malta.astype(float)
milexp_g20.Netherlands = milexp_g20.Netherlands.astype(float)
milexp_g20.Poland = milexp_g20.Poland.astype(float)
milexp_g20.Portugal = milexp_g20.Portugal.astype(float)
milexp_g20.Romania = milexp_g20.Romania.astype(float)
milexp_g20.Slovenia = milexp_g20.Slovenia.astype(float)
milexp_g20.Spain = milexp_g20.Spain.astype(float)
milexp_g20.Sweden = milexp_g20.Sweden.astype(float)
milexp_g20.Greece = milexp_g20.Greece.astype(float)
milexp_g20['United States'] = milexp_g20['United States'].astype(float)
milexp_g20['Russian Federation'] = milexp_g20['Russian Federation'].astype(float)
milexp_g20['European Union'] = milexp_g20['European Union'].astype(float)
milexp_g20['South Korea'] = milexp_g20['South Korea'].astype(float)
milexp_g20['Saudi Arabia'] = milexp_g20['Saudi Arabia'].astype(float)
milexp_g20['South Africa'] = milexp_g20['South Africa'].astype(float)
milexp_g20['United Kingdom'] = milexp_g20['United Kingdom'].astype(float)
milexp_g20['Czech Republic'] = milexp_g20['Czech Republic'].astype(float)

# %%
land_area = pd.read_csv('/content/drive/MyDrive/dataset/land_area.csv')

# %%
land_area["Country Name"].replace({"Korea, Rep.": "South Korea"},inplace=True)
land_g20 = land_area[land_area['Country Name'].isin(g20)]
land_g20 = land_g20.T.reset_index()
land_g20.columns = land_g20.iloc[0]
land_g20 = land_g20.drop([0,1,2,3]).reset_index()
land_g20 = land_g20.drop('index', axis=1)
land_g20 = land_g20.rename(columns = {'Country Name': 'Years'})
land_g20 = land_g20[land_g20['Years'] != 'Unnamed: 64']
land_g20['Years'] = land_g20['Years'].astype(int)
land_g20 = land_g20[land_g20['Years'] > 1990]
land_g20.China = land_g20.China.astype(float)
land_g20.India = land_g20.India.astype(float)
land_g20.Brazil = land_g20.Brazil.astype(float)
land_g20.Argentina = land_g20.Argentina.astype(float)
land_g20.Australia = land_g20.Australia.astype(float)
land_g20.Canada = land_g20.Canada.astype(float)
land_g20.France = land_g20.France.astype(float)
land_g20.Germany = land_g20.Germany.astype(float)
land_g20.Indonesia = land_g20.Indonesia.astype(float)
land_g20.Italy = land_g20.Italy.astype(float)
land_g20.Japan = land_g20.Japan.astype(float)
land_g20.Mexico = land_g20.Mexico.astype(float)
land_g20.Austria = land_g20.Austria.astype(float)
land_g20.Turkey = land_g20.Turkey.astype(float)
land_g20.Belgium = land_g20.Belgium.astype(float)
land_g20.Bulgaria = land_g20.Bulgaria.astype(float)
land_g20.Croatia = land_g20.Croatia.astype(float)
land_g20.Cyprus = land_g20.Cyprus.astype(float)
land_g20.Denmark = land_g20.Denmark.astype(float)
land_g20.Estonia = land_g20.Estonia.astype(float)
land_g20.Finland = land_g20.Finland.astype(float)
land_g20.Hungary = land_g20.Hungary.astype(float)
land_g20.Ireland = land_g20.Ireland.astype(float)
land_g20.Latvia = land_g20.Latvia.astype(float)
land_g20.Lithuania = land_g20.Lithuania.astype(float)
land_g20.Luxembourg = land_g20.Luxembourg.astype(float)
land_g20.Malta = land_g20.Malta.astype(float)
land_g20.Netherlands = land_g20.Netherlands.astype(float)
land_g20.Poland = land_g20.Poland.astype(float)
land_g20.Portugal = land_g20.Portugal.astype(float)
land_g20.Romania = land_g20.Romania.astype(float)
land_g20.Slovenia = land_g20.Slovenia.astype(float)
land_g20.Spain = land_g20.Spain.astype(float)
land_g20.Sweden = land_g20.Sweden.astype(float)
land_g20.Greece = land_g20.Greece.astype(float)
land_g20['United States'] = land_g20['United States'].astype(float)
land_g20['Russian Federation'] = land_g20['Russian Federation'].astype(float)
land_g20['European Union'] = land_g20['European Union'].astype(float)
land_g20['South Korea'] = land_g20['South Korea'].astype(float)
land_g20['Saudi Arabia'] = land_g20['Saudi Arabia'].astype(float)
land_g20['South Africa'] = land_g20['South Africa'].astype(float)
land_g20['United Kingdom'] = land_g20['United Kingdom'].astype(float)
land_g20['Czech Republic'] = land_g20['Czech Republic'].astype(float)

# %%
milexp_gdp.fillna(0,inplace=True)

# %%
h_clust = milexp_gdp[milexp_gdp['Country Name'].isin(g20)]
h_clust.drop(['Country Code','Indicator Name','Indicator Code'],axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
h_clust.reset_index(drop=True,inplace=True)
h_clust.columns
# Out:
# Index(['Country Name', '1960', '1961', '1962', '1963', '1964', '1965', '1966',
#        '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975',
#        '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984',
#        '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        'Unnamed: 64'],
#       dtype='object')

# %%
h_clust = h_clust[['Country Name','1990', '1991', '1992', '1993',
       '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
       '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
       '2012', '2013', '2014', '2015', '2016', '2017', '2018']]

# %%
# Find dataset misisng values.
dataset_info = h_clust.isnull().sum()/h_clust.shape[0]*100
dataset_info = dataset_info.reset_index()
dataset_info = dataset_info.rename(columns={'index': 'column_name',0:'missing %'})
# Find dataset types.
types = h_clust.dtypes.reset_index()
types = types.rename(columns = {0:'type'})
dataset_info['type'] = types['type']
# Find dataset total uniques.
uniques= h_clust.nunique().reset_index()
uniques = uniques.rename(columns = {0:'unique'})
dataset_info['unique'] = uniques['unique']
dataset_info.head(50)
# Out:
#      column_name  missing %     type  unique
# 0   Country Name        0.0   object      43
# 1           1990        0.0  float64      37
# 2           1991        0.0  float64      37
# 3           1992        0.0  float64      40
# 4           1993        0.0  float64      43
# 5           1994        0.0  float64      43
# 6           1995        0.0  float64      43
# 7           1996        0.0  float64      43
# 8           1997        0.0  float64      43
# 9           1998        0.0  float64      43
# 10          1999        0.0  float64      43
# 11          2000        0.0  float64      43
# 12          2001        0.0  float64      43
# 13          2002        0.0  float64      43
# 14          2003        0.0  float64      43
# 15          2004        0.0  float64      43
# 16          2005        0.0  float64      43
# 17          2006        0.0  float64      43
# 18          2007        0.0  float64      43
# 19          2008        0.0  float64      43
# ...

# %%
h_clust = h_clust.set_index('Country Name')

# %%
df1 = pd.read_csv('/content/drive/MyDrive/dataset/data baru.csv')
df1["Country Name"].replace({"Korea, Rep.": "South Korea"},inplace=True)
h_clust1 = df1[df1['Country Name'].isin(g20)]
h_clust1.drop(['Series Name','Series Code','Country Code'],axis=1,inplace=True)
h_clust1.replace(to_replace='..', value='0', inplace=True)
h_clust1.reset_index(drop=True,inplace=True)
h_clust1 = h_clust1.rename(columns={'1990 [YR1990]':'1990', '1991 [YR1991]':'1991', '1992 [YR1992]':'1992',
       '1993 [YR1993]':'1993', '1994 [YR1994]':'1994', '1995 [YR1995]':'1995', '1996 [YR1996]':'1996',
       '1997 [YR1997]':'1997', '1998 [YR1998]':'1998', '1999 [YR1999]':'1999', '2000 [YR2000]':'2000',
       '2001 [YR2001]':'2001', '2002 [YR2002]':'2002', '2003 [YR2003]':'2003', '2004 [YR2004]':'2004',
       '2005 [YR2005]':'2005', '2006 [YR2006]':'2006', '2007 [YR2007]':'2007', '2008 [YR2008]':'2008',
       '2009 [YR2009]':'2009', '2010 [YR2010]':'2010', '2011 [YR2011]':'2011', '2012 [YR2012]':'2012',
       '2013 [YR2013]':'2013', '2014 [YR2014]':'2014', '2015 [YR2015]':'2015', '2016 [YR2016]':'2016',
       '2017 [YR2017]':'2017', '2018 [YR2018]':'2018', '2019 [YR2019]':'2019', '2020 [YR2020]':'2020'})
h_clust1['1990'] = h_clust1['1990'].astype(float)
h_clust1['1991'] = h_clust1['1991'].astype(float)
h_clust1['1992'] = h_clust1['1992'].astype(float)
h_clust1['1993'] = h_clust1['1993'].astype(float)
h_clust1['1994'] = h_clust1['1994'].astype(float)
h_clust1['1995'] = h_clust1['1995'].astype(float)
h_clust1['1996'] = h_clust1['1996'].astype(float)
h_clust1['1997'] = h_clust1['1997'].astype(float)
h_clust1['1998'] = h_clust1['1998'].astype(float)
h_clust1['1999'] = h_clust1['1999'].astype(float)
h_clust1['2000'] = h_clust1['2000'].astype(float)
h_clust1['2001'] = h_clust1['2001'].astype(float)
h_clust1['2002'] = h_clust1['2002'].astype(float)
h_clust1['2003'] = h_clust1['2003'].astype(float)
h_clust1['2004'] = h_clust1['2004'].astype(float)
h_clust1['2005'] = h_clust1['2005'].astype(float)
h_clust1['2006'] = h_clust1['2006'].astype(float)
h_clust1['2007'] = h_clust1['2007'].astype(float)
h_clust1['2008'] = h_clust1['2008'].astype(float)
h_clust1['2009'] = h_clust1['2009'].astype(float)
h_clust1['2010'] = h_clust1['2010'].astype(float)
h_clust1['2011'] = h_clust1['2011'].astype(float)
h_clust1['2012'] = h_clust1['2012'].astype(float)
h_clust1['2013'] = h_clust1['2013'].astype(float)
h_clust1['2014'] = h_clust1['2014'].astype(float)
h_clust1['2015'] = h_clust1['2015'].astype(float)
h_clust1['2016'] = h_clust1['2016'].astype(float)
h_clust1['2017'] = h_clust1['2017'].astype(float)
h_clust1['2018'] = h_clust1['2018'].astype(float)
h_clust1['2019'] = h_clust1['2019'].astype(float)
h_clust1['2020'] = h_clust1['2020'].astype(float)
h_index = h_clust1.set_index('Country Name')
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
import seaborn as sns

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(24,15))
sns.heatmap(h_clust,cmap="YlGnBu",ax=ax1)
sns.heatmap(h_index,cmap="YlGnBu",ax=ax2)
ax1.set_ylabel('')
ax2.set_ylabel('')
ax1.set_title('Presentase Anggran Pertahanan Terhadap PDB')
ax2.set_title('Total Nominal Anggaran Pertahanan')
plt.savefig('heatmap.png',bbox_inches='tight');

# %%
cm = sns.clustermap(h_clust,cmap="YlOrBr",col_cluster=False,metric="correlation",figsize=[8,15])
cm.cax.set_visible(False)
cm.ax_row_dendrogram.set_visible(False)
cm.ax_col_dendrogram.set_visible(False)

plt.savefig('pic3.png');

# %%
from collections import defaultdict

import pandas as pd
from scipy.cluster.hierarchy import dendrogram, set_link_color_palette
import seaborn as sns
from matplotlib.colors import rgb2hex, colorConverter
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['cm']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
g20_fixed = ['United States', 'Russia', 'China', 'India', 'European Union', 'Brazil',
       'Argentina','Australia','Canada','France','Germany','Indonesia','Italy','Japan',
       'South Korea','Mexico','Saudi Arabia','South Africa','Turkey','United Kingdom','Austria','Belgium','Bulgaria','Croatia','Cyprus',
       'Czech Republic','Denmark','Estonia','Finland','Greece','Hungary','Ireland','Latvia','Lithuania','Luxembourg','Malta','Netherlands',
       'Poland','Portugal','Romania','Slovenia','Spain','Sweden']

# %%
df = pd.read_csv('/content/drive/MyDrive/dataset/global firepower 2022 wide.csv')
df = df[df['country'].isin(g20_fixed)]
df = df.drop(['country_code','Available Manpower',
        'External Debt',
       'Fit-for-Service', 'Foreign Exchange/Gold', 'Labor Force',
       'Merchant Marine Fleet', 
       'Oil Consumption', 'Oil Production', 'Oil Proven Reserves',
       'Paramilitary', 'Ports / Trade Terminals',
       'Purchasing Power Parity', 'Railway Coverage',
       'Reaching Mil Age Annually', 'Reserve Personnel', 'Roadway Coverage',
       'Shared Borders','Coastline Coverage',
       'Special-Mission','Tanker Fleet',
       'Total Aircraft Strength',
       'Trainers', 'Transports', 'Waterways (usable)','Total Population','Square Land Area'], axis=1)
df = df.set_index('country')

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)

# %%
scaled_df = pd.DataFrame(scaled_data,columns=df.columns,index=df.index)

# %%
Z = linkage(scaled_df, method='ward', metric='euclidean')
figsize(24,13)
den = dendrogram(Z,labels=scaled_df.index,orientation='right',distance_sort='descending',show_leaf_counts=False,color_threshold=1)
plt.xticks(rotation=90)
no_spine = {'left': True, 'bottom': True, 'right': True, 'top': True}
sns.despine(**no_spine);

# %%
milexpgov = pd.read_csv('/content/drive/MyDrive/dataset/mill exp govt.csv')

# %%
milexpgov["Country Name"].replace({"Korea, Rep.": "South Korea"},inplace=True)
milexpgov_g20 = milexpgov[milexpgov['Country Name'].isin(g20)]
milexpgov_g20 = milexpgov_g20.T.reset_index()
milexpgov_g20.columns = milexpgov_g20.iloc[0]
milexpgov_g20 = milexpgov_g20.drop([0,1,2,3]).reset_index()
milexpgov_g20 = milexpgov_g20.drop('index', axis=1)
milexpgov_g20 = milexpgov_g20.rename(columns = {'Country Name': 'Years'})
milexpgov_g20 = milexpgov_g20[milexpgov_g20['Years'] != 'Unnamed: 64']
milexpgov_g20['Years'] = milexpgov_g20['Years'].astype(int)
milexpgov_g20 = milexpgov_g20[milexpgov_g20['Years'] > 1990]
milexpgov_g20.China = milexpgov_g20.China.astype(float)
milexpgov_g20.India = milexpgov_g20.India.astype(float)
milexpgov_g20.Brazil = milexpgov_g20.Brazil.astype(float)
milexpgov_g20.Argentina = milexpgov_g20.Argentina.astype(float)
milexpgov_g20.Australia = milexpgov_g20.Australia.astype(float)
milexpgov_g20.Canada = milexpgov_g20.Canada.astype(float)
milexpgov_g20.France = milexpgov_g20.France.astype(float)
milexpgov_g20.Germany = milexpgov_g20.Germany.astype(float)
milexpgov_g20.Indonesia = milexpgov_g20.Indonesia.astype(float)
milexpgov_g20.Italy = milexpgov_g20.Italy.astype(float)
milexpgov_g20.Japan = milexpgov_g20.Japan.astype(float)
milexpgov_g20.Mexico = milexpgov_g20.Mexico.astype(float)
milexpgov_g20.Austria = milexpgov_g20.Austria.astype(float)
milexpgov_g20.Turkey = milexpgov_g20.Turkey.astype(float)
milexpgov_g20.Belgium = milexpgov_g20.Belgium.astype(float)
milexpgov_g20.Bulgaria = milexpgov_g20.Bulgaria.astype(float)
milexpgov_g20.Croatia = milexpgov_g20.Croatia.astype(float)
milexpgov_g20.Cyprus = milexpgov_g20.Cyprus.astype(float)
milexpgov_g20.Denmark = milexpgov_g20.Denmark.astype(float)
milexpgov_g20.Estonia = milexpgov_g20.Estonia.astype(float)
milexpgov_g20.Finland = milexpgov_g20.Finland.astype(float)
milexpgov_g20.Hungary = milexpgov_g20.Hungary.astype(float)
milexpgov_g20.Ireland = milexpgov_g20.Ireland.astype(float)
milexpgov_g20.Latvia = milexpgov_g20.Latvia.astype(float)
milexpgov_g20.Lithuania = milexpgov_g20.Lithuania.astype(float)
milexpgov_g20.Luxembourg = milexpgov_g20.Luxembourg.astype(float)
milexpgov_g20.Malta = milexpgov_g20.Malta.astype(float)
milexpgov_g20.Netherlands = milexpgov_g20.Netherlands.astype(float)
milexpgov_g20.Poland = milexpgov_g20.Poland.astype(float)
milexpgov_g20.Portugal = milexpgov_g20.Portugal.astype(float)
milexpgov_g20.Romania = milexpgov_g20.Romania.astype(float)
milexpgov_g20.Slovenia = milexpgov_g20.Slovenia.astype(float)
milexpgov_g20.Spain = milexpgov_g20.Spain.astype(float)
milexpgov_g20.Sweden = milexpgov_g20.Sweden.astype(float)
milexpgov_g20.Greece = milexpgov_g20.Greece.astype(float)
milexpgov_g20['United States'] = milexpgov_g20['United States'].astype(float)
milexpgov_g20['Russian Federation'] = milexpgov_g20['Russian Federation'].astype(float)
milexpgov_g20['European Union'] = milexpgov_g20['European Union'].astype(float)
milexpgov_g20['South Korea'] = milexpgov_g20['South Korea'].astype(float)
milexpgov_g20['Saudi Arabia'] = milexpgov_g20['Saudi Arabia'].astype(float)
milexpgov_g20['South Africa'] = milexpgov_g20['South Africa'].astype(float)
milexpgov_g20['United Kingdom'] = milexpgov_g20['United Kingdom'].astype(float)
milexpgov_g20['Czech Republic'] = milexpgov_g20['Czech Republic'].astype(float)

# %% [markdown]
# #NEW

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(20,10))
ax = plt.gca()
af_g20.plot(kind='line',x='Years',y='Japan',ax=ax1)
af_g20.plot(kind='line',x='Years',y='China',ax=ax1)
af_g20.plot(kind='line',x='Years',y='India',ax=ax1)
af_g20.plot(kind='line',x='Years',y='Indonesia',ax=ax1)
af_g20.plot(kind='line',x='Years',y='South Korea',ax=ax1)
af_g20.plot(kind='line',x='Years',y='Saudi Arabia',ax=ax1)

af_g20.plot(kind='line',x='Years',y='United States',ax=ax2)
af_g20.plot(kind='line',x='Years',y='China',ax=ax2)
af_g20.plot(kind='line',x='Years',y='India',ax=ax2)
af_g20.plot(kind='line',x='Years',y='Indonesia',ax=ax2)
af_g20.plot(kind='line',x='Years',y='European Union',ax=ax2)
af_g20.plot(kind='line',x='Years',y='Brazil',ax=ax2)
#ax1.get_legend().remove()
ax1.set_title('Total Armed Forces Based On Asia Region')
ax2.set_title('Total Armed Forces Based On Largest Population')
ax1.legend(fontsize=10)
ax2.legend(fontsize=10)
ax1.set_xlabel('')
ax2.set_xlabel('')
ax1.ticklabel_format(useOffset=False, style='plain')
ax2.ticklabel_format(useOffset=False, style='plain')
plt.show()

#fig.savefig('test1.png')

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(20,10))
ax = plt.gca()
af_g20.plot(kind='line',x='Years',y='Mexico',ax=ax1)
af_g20.plot(kind='line',x='Years',y='South Africa',ax=ax1)
af_g20.plot(kind='line',x='Years',y='Saudi Arabia',ax=ax1)
af_g20.plot(kind='line',x='Years',y='Indonesia',ax=ax1)

land_g20.plot(kind='line',x='Years',y='Mexico',ax=ax2)
land_g20.plot(kind='line',x='Years',y='South Africa',ax=ax2)
land_g20.plot(kind='line',x='Years',y='Saudi Arabia',ax=ax2)
land_g20.plot(kind='line',x='Years',y='Indonesia',ax=ax2)
ax1.get_legend().remove()
ax1.set_title('Total Armed Force Based on Area Similarities')
ax2.set_title('Land Area (square KM)')
#ax1.set_ylabel('Million')
#ax1.legend(fontsize=10)
#ax2.legend(fontsize=10)
ax1.set_xlabel('')
ax2.set_xlabel('')
ax1.ticklabel_format(useOffset=False, style='plain')
ax2.ticklabel_format(useOffset=False, style='plain')
plt.show()

#fig.savefig('test1.png')

# %%
fig,((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2,figsize=(20,15))
ax = plt.gca()
milexpgov_g20.plot(kind='line',x='Years',y='Japan',ax=ax1)
milexpgov_g20.plot(kind='line',x='Years',y='China',ax=ax1)
milexpgov_g20.plot(kind='line',x='Years',y='India',ax=ax1)
milexpgov_g20.plot(kind='line',x='Years',y='Indonesia',ax=ax1)
milexpgov_g20.plot(kind='line',x='Years',y='South Korea',ax=ax1)
milexpgov_g20.plot(kind='line',x='Years',y='Saudi Arabia',ax=ax1)

milexpgov_g20.plot(kind='line',x='Years',y='Mexico',ax=ax2)
milexpgov_g20.plot(kind='line',x='Years',y='Turkey',ax=ax2)
milexpgov_g20.plot(kind='line',x='Years',y='Netherlands',ax=ax2)
milexpgov_g20.plot(kind='line',x='Years',y='Indonesia',ax=ax2)
milexpgov_g20.plot(kind='line',x='Years',y='Brazil',ax=ax2)
milexpgov_g20.plot(kind='line',x='Years',y='Saudi Arabia',ax=ax2)

milexp_g20.plot(kind='line',x='Years',y='Japan',ax=ax3)
milexp_g20.plot(kind='line',x='Years',y='China',ax=ax3)
milexp_g20.plot(kind='line',x='Years',y='India',ax=ax3)
milexp_g20.plot(kind='line',x='Years',y='Indonesia',ax=ax3)
milexp_g20.plot(kind='line',x='Years',y='South Korea',ax=ax3)
milexp_g20.plot(kind='line',x='Years',y='Saudi Arabia',ax=ax3)

milexp_g20.plot(kind='line',x='Years',y='Mexico',ax=ax4)
milexp_g20.plot(kind='line',x='Years',y='Turkey',ax=ax4)
milexp_g20.plot(kind='line',x='Years',y='Netherlands',ax=ax4)
milexp_g20.plot(kind='line',x='Years',y='Indonesia',ax=ax4)
milexp_g20.plot(kind='line',x='Years',y='Brazil',ax=ax4)
milexp_g20.plot(kind='line',x='Years',y='Saudi Arabia',ax=ax4)
#ax1.get_legend().remove()
ax1.set_title('Total Military Budget Based On Asia Region')
ax2.set_title('Total Military Budget Based On GDP Similarities')
ax3.set_title('Military Expenditure as a % of GDP In Region')
ax4.set_title('Military Expenditure as a % of GDP Similarities')
ax1.set_ylabel('Percentage')
ax2.set_ylabel('Percentage')
ax3.set_ylabel('Percentage')
ax4.set_ylabel('Percentage')
ax1.legend(fontsize=10)
ax2.legend(fontsize=10)
ax3.legend(fontsize=10)
ax4.legend(fontsize=10)
ax1.set_xlabel('')
ax2.set_xlabel('')
ax3.set_xlabel('')
ax4.set_xlabel('')
plt.show()

#fig.savefig('test1.png')

# %%
data = pd.read_csv(r'/content/drive/MyDrive/dataset/Military Expenditure.csv')
data.head()
# Out:
#           Name Code     Type                      Indicator Name  1960  1961  \
# 0        Aruba  ABW  Country  Military expenditure (current USD)   NaN   NaN
# 1  Afghanistan  AFG  Country  Military expenditure (current USD)   NaN   NaN
# 2       Angola  AGO  Country  Military expenditure (current USD)   NaN   NaN
# 3      Albania  ALB  Country  Military expenditure (current USD)   NaN   NaN
# 4      Andorra  AND  Country  Military expenditure (current USD)   NaN   NaN
#
#    1962  1963  1964  1965  ...          2009          2010          2011  \
# 0   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
# 1   NaN   NaN   NaN   NaN  ...  2.518695e+08  2.981469e+08  3.258070e+08
# 2   NaN   NaN   NaN   NaN  ...  3.311193e+09  3.500795e+09  3.639496e+09
# 3   NaN   NaN   NaN   NaN  ...  1.827369e+08  1.858932e+08  1.970068e+08
# 4   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
#
# ...

# %%
g20_only = ['United States', 'Russian Federation', 'China', 'India', 'European Union', 'Brazil',
       'Argentina','Australia','Canada','France','Germany','Indonesia','Italy','Japan',
       'South Korea','Mexico','Saudi Arabia','South Africa','Turkey','United Kingdom']
eu_member = ['France','Germany','Italy','Austria','Belgium','Bulgaria','Croatia','Cyprus',
       'Czech Republic','Denmark','Estonia','Finland','Greece','Hungary','Ireland','Latvia','Lithuania','Luxembourg','Malta','Netherlands',
       'Poland','Portugal','Romania','Slovenia','Spain','Sweden']

# %%
Nations = data[data['Name'].isin(g20_only)]
Nations = Nations.drop(['Code', 'Type'], axis=1)
Nations = Nations.set_index('Name')
Nations.index = Nations.index.rename('Year')
Nations.fillna(0,inplace=True)
Nations = Nations.T
Nations = Nations[30:]

# %%
eu = data[data['Name'].isin(eu_member)]
eu = eu.drop(['Code', 'Type'], axis=1)
eu = eu.set_index('Name')
eu.index = eu.index.rename('Year')
eu.fillna(0,inplace=True)
eu = eu.T
eu = eu[30:]

# %%
Top10_eu = pd.DataFrame((eu.T['2018']).sort_values(ascending=False)[:10])
Top10_eu = Top10_eu/1e9
Top10_eu.index = Top10_eu.index.rename('Country')
Top10_eu = Top10_eu.rename(columns={'2018':'Billion $'})
Top10_eu
# Out:
#              Billion $
# Country
# France       63.799677
# Germany      49.470628
# Italy        27.807514
# Spain        18.248291
# Poland       11.596155
# Netherlands  11.242756
# Sweden        5.755368
# Greece        5.227152
# Belgium       4.959692
# Romania       4.608674

# %%
Top_10 = pd.DataFrame((Nations.T['2018']).sort_values(ascending=False)[:10])
Top_10 = Top_10/1e9
Top_10.index = Top_10.index.rename('Country')
Top_10 = Top_10.rename(columns={'2018':'Billion $'})
Top_10
# Out:
#                     Billion $
# Country
# United States           649.0
# European Union          281.0
# China                   250.0
# Saudi Arabia        67.554667
# India               66.510289
# France              63.799677
# Russian Federation  61.387547
# United Kingdom      49.997193
# Germany             49.470628
# Japan               46.617955

# %%
Bot_10 = pd.DataFrame((Nations.T['2018']).sort_values(ascending=False)[10:])
Bot_10 = Bot_10/1e9
Bot_10.index = Bot_10.index.rename('Country')
Bot_10 = Bot_10.rename(columns={'2018':'Billion $'})
Bot_10
# Out:
#               Billion $
# Country
# South Korea   43.069973
# Italy         27.807514
# Brazil        27.766427
# Australia     26.711834
# Canada        21.620599
# Turkey        18.967113
# Indonesia      7.437197
# Mexico         6.567509
# Argentina      4.144992
# South Africa   3.639879

# %%
plt.figure(figsize=(8, 8))
Top_10.plot(kind='bar')
plt.xlabel('')
plt.title('Top 10 Military Spending')
plt.show();

# %%
plt.figure(figsize=(8, 8))
Bot_10.plot(kind='bar')
plt.xlabel('')
plt.title('Bottom 10 Military Spending')
plt.show();

# %%
X1 = Nations.T.reset_index()
X1.rename(columns={"Year": "Country"},inplace=True)

# %%
X2 = eu.T.reset_index()
X2.rename(columns={"Year": "Country"},inplace=True)

# %%
fig, ax = plt.subplots(1,figsize = (11,12))
sns.barplot(y='Country', x='2018',data=X2.sort_values('2018', ascending=False),color="Blue",ax=ax)
plt.xlabel('Billions $')
plt.title('European Union Military Spending')
ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x)/1e9,',')))
ax.set_xlabel('')
plt.show()

# %%
fig, ax = plt.subplots(1,figsize = (8,8))
sns.barplot(y='Country', x='2018',data=X1.sort_values('2018', ascending=False)[:10],color="Green",ax=ax)
plt.xlabel('Billions')
plt.title('G20 Top Military Spending')
ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x)/1e9,',')))
plt.show()

# %%
fig, ax = plt.subplots(1,figsize = (8,8))
sns.barplot(y='Country', x='2018',data=X1.sort_values('2018', ascending=False)[10:],color="Red",ax=ax)
plt.xlabel('Billions')
plt.title('G20 Top Military Spending')
ax.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x)/1e9,',')))
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(2,figsize = (8,8))
sns.barplot(y='Country', x='2018',data=X1.sort_values('2018', ascending=False)[:10],color="Green",ax=ax1)
sns.barplot(y='Country', x='2018',data=X1.sort_values('2018', ascending=False)[10:],color="Red",ax=ax2)
ax1.set_ylabel('')
ax2.set_ylabel('')
ax1.set_xlabel('')
ax2.set_xlabel('Billions $')
ax1.set_title('G20 Top and Bottom Military Spending')
ax1.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x)/1e9,',')))
ax2.get_xaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x)/1e9,',')))

# %%
df = pd.read_csv('/content/drive/MyDrive/dataset/global firepower 2022 wide.csv')

# %%
d = pd.melt(df,'country', var_name='Eqipment', value_name='Total')
print(d.head())
# Out:
#        country      Eqipment Total
# 0  Afghanistan  country_code   AFG
# 1      Albania  country_code   ALB
# 2      Algeria  country_code   ALG
# 3       Angola  country_code   ANG
# 4    Argentina  country_code   ARG

# %%
d.to_excel(r'output1.xlsx', sheet_name='data', index=False)

# %%
df = df[df['country'].isin(g20_only)]
df = df.drop(['country_code'], axis=1)
df = df.set_index('country')
